# %% [markdown]
# # Projet d'analyse de données : Une analyse du conflit politique
#
# _Laura Souverin, Clélia Desjean, Anaïs Noe, Marwan Noua_
#
# ---
#
# Nous nous appuyons sur un jeu de données issues du livre Julia Cagé et Thomas Piketty (2023) : Une histoire du conflit politique. Élections et inégalités sociales en France, 1789-2022, Paris, Le Seuil.
# Notre objectif est d'essayer comprendre si certaines variables permettent d'expliquer les votes par communes aux élections législatives de 2022.

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import polars as pl

# %matplotlib inline

# %% [markdown]
# ## Data Loading
#
# _Note:_ In Python, [colormap](https://matplotlib.org/stable/users/explain/colors/colormaps.html) allows easier dataframe visualization.

# %%
data = pd.read_csv('HR-Employee-Attrition.csv')

display( 
    data.head().style.background_gradient(cmap='BuPu')
)
# Out:
# <style type="text/css">
# #T_1350a_row0_col0 {
#   background-color: #8c68af;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col3 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col5, #T_1350a_row0_col8, #T_1350a_row0_col9, #T_1350a_row0_col23, #T_1350a_row0_col24, #T_1350a_row0_col25, #T_1350a_row0_col26, #T_1350a_row0_col27, #T_1350a_row0_col29, #T_1350a_row0_col30, #T_1350a_row0_col33, #T_1350a_row1_col3, #T_1350a_row1_col6, #T_1350a_row1_col8, #T_1350a_row1_col13, #T_1350a_row1_col16, #T_1350a_row1_col20, #T_1350a_row1_col26, #T_1350a_row2_col8, #T_1350a_row2_col13, #T_1350a_row2_col14, #T_1350a_row2_col18, #T_1350a_row2_col19, #T_1350a_row2_col24, #T_1350a_row2_col26, #T_1350a_row2_col27, #T_1350a_row2_col31, #T_1350a_row2_col32, #T_1350a_row2_col33, #T_1350a_row2_col34, #T_1350a_row3_col8, #T_1350a_row3_col14, #T_1350a_row3_col20, #T_1350a_row3_col23, #T_1350a_row3_col24, #T_1350a_row3_col26, #T_1350a_row3_col27, #T_1350a_row3_col34, #T_1350a_row4_col0, #T_1350a_row4_col6, #T_1350a_row4_col8, #T_1350a_row4_col10, #T_1350a_row4_col12, #T_1350a_row4_col14, #T_1350a_row4_col16, #T_1350a_row4_col24, #T_1350a_row4_col26, #T_1350a_row4_col28 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_1350a_row0_col6, #T_1350a_row0_col10, #T_1350a_row1_col33, #T_1350a_row2_col6, #T_1350a_row2_col23, #T_1350a_row2_col25 {
#   background-color: #a9c4de;
#   color: #000000;
# }
# #T_1350a_row0_col12, #T_1350a_row0_col13, #T_1350a_row0_col14, #T_1350a_row0_col16, #T_1350a_row0_col18, #T_1350a_row1_col0, #T_1350a_row1_col5, #T_1350a_row1_col14, #T_1350a_row1_col19, #T_1350a_row1_col23, #T_1350a_row1_col24, #T_1350a_row1_col25, #T_1350a_row1_col27, #T_1350a_row1_col28, #T_1350a_row1_col29, #T_1350a_row1_col30, #T_1350a_row1_col31, #T_1350a_row1_col32, #T_1350a_row1_col34, #T_1350a_row2_col10, #T_1350a_row2_col29, #T_1350a_row2_col30, #T_1350a_row3_col3, #T_1350a_row3_col6, #T_1350a_row3_col10, #T_1350a_row3_col13, #T_1350a_row3_col29, #T_1350a_row3_col30, #T_1350a_row3_col32, #T_1350a_row3_col33, #T_1350a_row4_col9, #T_1350a_row4_col13, #T_1350a_row4_col20, #T_1350a_row4_col25, #T_1350a_row4_col27, #T_1350a_row4_col29, #T_1350a_row4_col30 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col19 {
#   background-color: #873d9a;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col20 {
#   background-color: #800f7b;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col28, #T_1350a_row2_col9, #T_1350a_row2_col16, #T_1350a_row3_col16, #T_1350a_row3_col28 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col31 {
#   background-color: #8c74b5;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col32 {
#   background-color: #8c7dba;
#   color: #f1f1f1;
# }
# #T_1350a_row0_col34 {
#   background-color: #894da3;
#   color: #f1f1f1;
# }
# #T_1350a_row1_col9 {
#   background-color: #d6e4f0;
#   color: #000000;
# }
# #T_1350a_row1_col10, #T_1350a_row3_col9, #T_1350a_row3_col25, #T_1350a_row4_col33 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_1350a_row1_col12 {
#   background-color: #9cb8d8;
#   color: #000000;
# }
# #T_1350a_row1_col18 {
#   background-color: #863595;
#   color: #f1f1f1;
# }
# #T_1350a_row2_col0 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_1350a_row2_col3 {
#   background-color: #540251;
#   color: #f1f1f1;
# }
# #T_1350a_row2_col5, #T_1350a_row4_col5 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_1350a_row2_col12 {
#   background-color: #5c0459;
#   color: #f1f1f1;
# }
# #T_1350a_row2_col20 {
#   background-color: #8c6ab1;
#   color: #f1f1f1;
# }
# #T_1350a_row2_col28 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_1350a_row3_col0 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_1350a_row3_col5, #T_1350a_row4_col32, #T_1350a_row4_col34 {
#   background-color: #b5cce3;
#   color: #000000;
# }
# #T_1350a_row3_col12 {
#   background-color: #b3cbe2;
#   color: #000000;
# }
# #T_1350a_row3_col18 {
#   background-color: #cadbeb;
#   color: #000000;
# }
# #T_1350a_row3_col19 {
#   background-color: #6c0968;
#   color: #f1f1f1;
# }
# #T_1350a_row3_col31 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_1350a_row4_col3 {
#   background-color: #b7cee3;
#   color: #000000;
# }
# #T_1350a_row4_col18 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_1350a_row4_col19 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_1350a_row4_col23 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_1350a_row4_col31 {
#   background-color: #ccddec;
#   color: #000000;
# }
# </style>
# <table id="T_1350a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1350a_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_1350a_level0_col1" class="col_heading level0 col1" >Attrition</th>
#       <th id="T_1350a_level0_col2" class="col_heading level0 col2" >BusinessTravel</th>
#       <th id="T_1350a_level0_col3" class="col_heading level0 col3" >DailyRate</th>
#       <th id="T_1350a_level0_col4" class="col_heading level0 col4" >Department</th>
#       <th id="T_1350a_level0_col5" class="col_heading level0 col5" >DistanceFromHome</th>
#       <th id="T_1350a_level0_col6" class="col_heading level0 col6" >Education</th>
#       <th id="T_1350a_level0_col7" class="col_heading level0 col7" >EducationField</th>
#       <th id="T_1350a_level0_col8" class="col_heading level0 col8" >EmployeeCount</th>
#       <th id="T_1350a_level0_col9" class="col_heading level0 col9" >EmployeeNumber</th>
#       <th id="T_1350a_level0_col10" class="col_heading level0 col10" >EnvironmentSatisfaction</th>
#       <th id="T_1350a_level0_col11" class="col_heading level0 col11" >Gender</th>
#       <th id="T_1350a_level0_col12" class="col_heading level0 col12" >HourlyRate</th>
#       <th id="T_1350a_level0_col13" class="col_heading level0 col13" >JobInvolvement</th>
#       <th id="T_1350a_level0_col14" class="col_heading level0 col14" >JobLevel</th>
#       <th id="T_1350a_level0_col15" class="col_heading level0 col15" >JobRole</th>
#       <th id="T_1350a_level0_col16" class="col_heading level0 col16" >JobSatisfaction</th>
#       <th id="T_1350a_level0_col17" class="col_heading level0 col17" >MaritalStatus</th>
#       <th id="T_1350a_level0_col18" class="col_heading level0 col18" >MonthlyIncome</th>
#       <th id="T_1350a_level0_col19" class="col_heading level0 col19" >MonthlyRate</th>
#       <th id="T_1350a_level0_col20" class="col_heading level0 col20" >NumCompaniesWorked</th>
#       <th id="T_1350a_level0_col21" class="col_heading level0 col21" >Over18</th>
#       <th id="T_1350a_level0_col22" class="col_heading level0 col22" >OverTime</th>
#       <th id="T_1350a_level0_col23" class="col_heading level0 col23" >PercentSalaryHike</th>
#       <th id="T_1350a_level0_col24" class="col_heading level0 col24" >PerformanceRating</th>
#       <th id="T_1350a_level0_col25" class="col_heading level0 col25" >RelationshipSatisfaction</th>
#       <th id="T_1350a_level0_col26" class="col_heading level0 col26" >StandardHours</th>
#       <th id="T_1350a_level0_col27" class="col_heading level0 col27" >StockOptionLevel</th>
#       <th id="T_1350a_level0_col28" class="col_heading level0 col28" >TotalWorkingYears</th>
#       <th id="T_1350a_level0_col29" class="col_heading level0 col29" >TrainingTimesLastYear</th>
#       <th id="T_1350a_level0_col30" class="col_heading level0 col30" >WorkLifeBalance</th>
#       <th id="T_1350a_level0_col31" class="col_heading level0 col31" >YearsAtCompany</th>
#       <th id="T_1350a_level0_col32" class="col_heading level0 col32" >YearsInCurrentRole</th>
#       <th id="T_1350a_level0_col33" class="col_heading level0 col33" >YearsSinceLastPromotion</th>
#       <th id="T_1350a_level0_col34" class="col_heading level0 col34" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1350a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1350a_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_1350a_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_1350a_row0_col2" class="data row0 col2" >Travel_Rarely</td>
#       <td id="T_1350a_row0_col3" class="data row0 col3" >1102</td>
#       <td id="T_1350a_row0_col4" class="data row0 col4" >Sales</td>
#       <t

# %% [markdown]
# For each employee, we observe the following 35 variables:
# * `Age` : Age in years of the employee
# * `Attrition` : People who people leave
# * `BusinessTravel` : How often an employee embark on a job related travel
# * `DailyRate` : Daily rate at which an employee is paid
# * `Department` : Department where the employee works
# * `DistanceFromHome` : Distance an employee travels from home to work
# * `Education` : Level of education of the employee
# * `EducationField` : What field the employee studied in school
# * `EmployeeCount` : Count of employee
# * `EmployeeNumber` : EMployee number
# * `EnvironmentSatisfaction` : Employee environment satisfaction
# * `Gender` : Gender of the employee
# * `HourlyRate` : Hourly rate of pay of the employee
# * `JobInvolvement` : Employee job involvement ratings
# * `JobLevel` : Employee Job level
# * `JobRole` : Employee Job role
# * `JobSatisfaction` : Employee Job Staisfaction
# * `MaritalStatus` : Employee Marital Status
# * `MonthlyIncome` : Employee monthly income
# * `MonthlyRate` : Employee Monthly rate
# * `NumCompaniesWorked` : Number of companies worked
# * `Over18` : Age over 18 years
# * `OverTime` : Work overtime
# * `PercentSalaryHike` : Salary increment in Percentages
# * `PerformanceRating` : Performance rating
# * `RelationshipSatisfaction` : Relationship satisfaction
# * `StandardHours` : Employee standard hours worked
# * `StockOptionLevel` : Stock options level
# * `TotalWorkingYears` : Total working hours
# * `TrainingTimesLastYear` : Total working years
# * `WorkLifeBalance` : Work life balance rating
# * `YearsAtCompany` : Years at the company
# * `YearsInCurrentRole` : Years in current role
# * `YearsSinceLastPromotion` : Years since last promotion
# * `YearsWithCurrManager` : Years with current manager

# %% [markdown]
# ##### <span style="color:purple"> **Question:** How many employees are we looking at? </span>

# %%
### TO BE COMPLETED ###
print(np.shape(data))
# Out:
# (1470, 35)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Check data quality.</span>
#
# 1. Does this dataset contain duplicate rows?
# 2. How many distinct (unique) values does each variable take?
# 3. How many empty cells are there in each column?
# 4. How are the variables encoded? What type?

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/data_quality.py
n_duplicated = data.duplicated().sum()
print(f"Number of duplicated rows: {n_duplicated}\n")

df = pd.DataFrame({
    'n_unique':data.nunique(),
    'n_missing':data.isna().sum(),
    'missing_ratio':data.isna().mean(),
    'dtype':data.dtypes.values
})

display(
    df.style.background_gradient(cmap='BuPu')
        .format({"missing_ratio": "{:.2%}"})
)
# Out:
# Number of duplicated rows: 0
# <style type="text/css">
# #T_956a1_row0_col0 {
#   background-color: #f2f8fb;
#   color: #000000;
# }
# #T_956a1_row0_col1, #T_956a1_row0_col2, #T_956a1_row1_col0, #T_956a1_row1_col1, #T_956a1_row1_col2, #T_956a1_row2_col0, #T_956a1_row2_col1, #T_956a1_row2_col2, #T_956a1_row3_col1, #T_956a1_row3_col2, #T_956a1_row4_col0, #T_956a1_row4_col1, #T_956a1_row4_col2, #T_956a1_row5_col1, #T_956a1_row5_col2, #T_956a1_row6_col0, #T_956a1_row6_col1, #T_956a1_row6_col2, #T_956a1_row7_col0, #T_956a1_row7_col1, #T_956a1_row7_col2, #T_956a1_row8_col0, #T_956a1_row8_col1, #T_956a1_row8_col2, #T_956a1_row9_col1, #T_956a1_row9_col2, #T_956a1_row10_col0, #T_956a1_row10_col1, #T_956a1_row10_col2, #T_956a1_row11_col0, #T_956a1_row11_col1, #T_956a1_row11_col2, #T_956a1_row12_col1, #T_956a1_row12_col2, #T_956a1_row13_col0, #T_956a1_row13_col1, #T_956a1_row13_col2, #T_956a1_row14_col0, #T_956a1_row14_col1, #T_956a1_row14_col2, #T_956a1_row15_col1, #T_956a1_row15_col2, #T_956a1_row16_col0, #T_956a1_row16_col1, #T_956a1_row16_col2, #T_956a1_row17_col0, #T_956a1_row17_col1, #T_956a1_row17_col2, #T_956a1_row18_col1, #T_956a1_row18_col2, #T_956a1_row19_col1, #T_956a1_row19_col2, #T_956a1_row20_col1, #T_956a1_row20_col2, #T_956a1_row21_col0, #T_956a1_row21_col1, #T_956a1_row21_col2, #T_956a1_row22_col0, #T_956a1_row22_col1, #T_956a1_row22_col2, #T_956a1_row23_col1, #T_956a1_row23_col2, #T_956a1_row24_col0, #T_956a1_row24_col1, #T_956a1_row24_col2, #T_956a1_row25_col0, #T_956a1_row25_col1, #T_956a1_row25_col2, #T_956a1_row26_col0, #T_956a1_row26_col1, #T_956a1_row26_col2, #T_956a1_row27_col0, #T_956a1_row27_col1, #T_956a1_row27_col2, #T_956a1_row28_col1, #T_956a1_row28_col2, #T_956a1_row29_col1, #T_956a1_row29_col2, #T_956a1_row30_col0, #T_956a1_row30_col1, #T_956a1_row30_col2, #T_956a1_row31_col1, #T_956a1_row31_col2, #T_956a1_row32_col1, #T_956a1_row32_col2, #T_956a1_row33_col1, #T_956a1_row33_col2, #T_956a1_row34_col1, #T_956a1_row34_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_956a1_row3_col0 {
#   background-color: #8c72b5;
#   color: #f1f1f1;
# }
# #T_956a1_row5_col0 {
#   background-color: #f4fafc;
#   color: #000000;
# }
# #T_956a1_row9_col0 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_956a1_row12_col0 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_956a1_row15_col0, #T_956a1_row20_col0, #T_956a1_row29_col0 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_956a1_row18_col0 {
#   background-color: #6f0a6b;
#   color: #f1f1f1;
# }
# #T_956a1_row19_col0 {
#   background-color: #580356;
#   color: #f1f1f1;
# }
# #T_956a1_row23_col0, #T_956a1_row33_col0, #T_956a1_row34_col0 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_956a1_row28_col0, #T_956a1_row31_col0 {
#   background-color: #f3f9fb;
#   color: #000000;
# }
# #T_956a1_row32_col0 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# </style>
# <table id="T_956a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_956a1_level0_col0" class="col_heading level0 col0" >n_unique</th>
#       <th id="T_956a1_level0_col1" class="col_heading level0 col1" >n_missing</th>
#       <th id="T_956a1_level0_col2" class="col_heading level0 col2" >missing_ratio</th>
#       <th id="T_956a1_level0_col3" class="col_heading level0 col3" >dtype</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_956a1_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_956a1_row0_col0" class="data row0 col0" >43</td>
#       <td id="T_956a1_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_956a1_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_956a1_row0_col3" class="data row0 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row1" class="row_heading level0 row1" >Attrition</th>
#       <td id="T_956a1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_956a1_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_956a1_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_956a1_row1_col3" class="data row1 col3" >str</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row2" class="row_heading level0 row2" >BusinessTravel</th>
#       <td id="T_956a1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_956a1_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_956a1_row2_col2" class="data row2 col2" >0.00%</td>
#       <td id="T_956a1_row2_col3" class="data row2 col3" >str</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row3" class="row_heading level0 row3" >DailyRate</th>
#       <td id="T_956a1_row3_col0" class="data row3 col0" >886</td>
#       <td id="T_956a1_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_956a1_row3_col2" class="data row3 col2" >0.00%</td>
#       <td id="T_956a1_row3_col3" class="data row3 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row4" class="row_heading level0 row4" >Department</th>
#       <td id="T_956a1_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_956a1_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_956a1_row4_col2" class="data row4 col2" >0.00%</td>
#       <td id="T_956a1_row4_col3" class="data row4 col3" >str</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row5" class="row_heading level0 row5" >DistanceFromHome</th>
#       <td id="T_956a1_row5_col0" class="data row5 col0" >29</td>
#       <td id="T_956a1_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_956a1_row5_col2" class="data row5 col2" >0.00%</td>
#       <td id="T_956a1_row5_col3" class="data row5 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row6" class="row_heading level0 row6" >Education</th>
#       <td id="T_956a1_row6_col0" class="data row6 col0" >5</td>
#       <td id="T_956a1_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_956a1_row6_col2" class="data row6 col2" >0.00%</td>
#       <td id="T_956a1_row6_col3" class="data row6 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row7" class="row_heading level0 row7" >EducationField</th>
#       <td id="T_956a1_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_956a1_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_956a1_row7_col2" class="data row7 col2" >0.00%</td>
#       <td id="T_956a1_row7_col3" class="data row7 col3" >str</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row8" class="row_heading level0 row8" >EmployeeCount</th>
#       <td id="T_956a1_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_956a1_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_956a1_row8_col2" class="data row8 col2" >0.00%</td>
#       <td id="T_956a1_row8_col3" class="data row8 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row9" class="row_heading level0 row9" >EmployeeNumber</th>
#       <td id="T_956a1_row9_col0" class="data row9 col0" >1470</td>
#       <td id="T_956a1_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_956a1_row9_col2" class="data row9 col2" >0.00%</td>
#       <td id="T_956a1_row9_col3" class="data row9 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row10" class="row_heading level0 row10" >EnvironmentSatisfaction</th>
#       <td id="T_956a1_row10_col0" class="data row10 col0" >4</td>
#       <td id="T_956a1_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_956a1_row10_col2" class="data row10 col2" >0.00%</td>
#       <td id="T_956a1_row10_col3" class="data row10 col3" >int64</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row11" class="row_heading level0 row11" >Gender</th>
#       <td id="T_956a1_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_956a1_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_956a1_row11_col2" class="data row11 col2" >0.00%</td>
#       <td id="T_956a1_row11_col3" class="data row11 col3" >str</td>
#     </tr>
#     <tr>
#       <th id="T_956a1_level0_row12" class="row_heading level0 row12" >HourlyRate</th>
#       <td id="T_956a1_row12_col0" class="data row12 col0" >71</td>
#       <td id="T_956a1_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_956a1_row12_col2" class="data row12 col2" >0.00%</td>
#       <

# %% [markdown]
# > Comments.

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Remove unnecessary columns.</span>
#
# Dropping columns that have:
# - Only _one_ inside it that doesn't contribute to the analysis
# - Columns that contain _index_ value
#
# Use pandas [`drop`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html) function.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/data_drop.py
cols_to_drop = [
    "EmployeeCount",
    "Over18",
    "StandardHours",
    "EmployeeNumber"
]
data = data.drop(columns=cols_to_drop)

display(
    data.head().style.background_gradient(cmap="BuPu")
)
# Out:
# <style type="text/css">
# #T_e8729_row0_col0 {
#   background-color: #8c68af;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col3 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col5, #T_e8729_row0_col20, #T_e8729_row0_col21, #T_e8729_row0_col22, #T_e8729_row0_col23, #T_e8729_row0_col25, #T_e8729_row0_col26, #T_e8729_row0_col29, #T_e8729_row1_col3, #T_e8729_row1_col6, #T_e8729_row1_col11, #T_e8729_row1_col14, #T_e8729_row1_col18, #T_e8729_row2_col11, #T_e8729_row2_col12, #T_e8729_row2_col16, #T_e8729_row2_col17, #T_e8729_row2_col21, #T_e8729_row2_col23, #T_e8729_row2_col27, #T_e8729_row2_col28, #T_e8729_row2_col29, #T_e8729_row2_col30, #T_e8729_row3_col12, #T_e8729_row3_col18, #T_e8729_row3_col20, #T_e8729_row3_col21, #T_e8729_row3_col23, #T_e8729_row3_col30, #T_e8729_row4_col0, #T_e8729_row4_col6, #T_e8729_row4_col8, #T_e8729_row4_col10, #T_e8729_row4_col12, #T_e8729_row4_col14, #T_e8729_row4_col21, #T_e8729_row4_col24 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_e8729_row0_col6, #T_e8729_row0_col8, #T_e8729_row1_col29, #T_e8729_row2_col6, #T_e8729_row2_col20, #T_e8729_row2_col22 {
#   background-color: #a9c4de;
#   color: #000000;
# }
# #T_e8729_row0_col10, #T_e8729_row0_col11, #T_e8729_row0_col12, #T_e8729_row0_col14, #T_e8729_row0_col16, #T_e8729_row1_col0, #T_e8729_row1_col5, #T_e8729_row1_col12, #T_e8729_row1_col17, #T_e8729_row1_col20, #T_e8729_row1_col21, #T_e8729_row1_col22, #T_e8729_row1_col23, #T_e8729_row1_col24, #T_e8729_row1_col25, #T_e8729_row1_col26, #T_e8729_row1_col27, #T_e8729_row1_col28, #T_e8729_row1_col30, #T_e8729_row2_col8, #T_e8729_row2_col25, #T_e8729_row2_col26, #T_e8729_row3_col3, #T_e8729_row3_col6, #T_e8729_row3_col8, #T_e8729_row3_col11, #T_e8729_row3_col25, #T_e8729_row3_col26, #T_e8729_row3_col28, #T_e8729_row3_col29, #T_e8729_row4_col11, #T_e8729_row4_col18, #T_e8729_row4_col22, #T_e8729_row4_col23, #T_e8729_row4_col25, #T_e8729_row4_col26 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col17 {
#   background-color: #873d9a;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col18 {
#   background-color: #800f7b;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col24, #T_e8729_row2_col14, #T_e8729_row3_col14, #T_e8729_row3_col24 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col27 {
#   background-color: #8c74b5;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col28 {
#   background-color: #8c7dba;
#   color: #f1f1f1;
# }
# #T_e8729_row0_col30 {
#   background-color: #894da3;
#   color: #f1f1f1;
# }
# #T_e8729_row1_col8, #T_e8729_row3_col22, #T_e8729_row4_col29 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_e8729_row1_col10 {
#   background-color: #9cb8d8;
#   color: #000000;
# }
# #T_e8729_row1_col16 {
#   background-color: #863595;
#   color: #f1f1f1;
# }
# #T_e8729_row2_col0 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_e8729_row2_col3 {
#   background-color: #540251;
#   color: #f1f1f1;
# }
# #T_e8729_row2_col5, #T_e8729_row4_col5 {
#   background-color: #dce9f2;
#   color: #000000;
# }
# #T_e8729_row2_col10 {
#   background-color: #5c0459;
#   color: #f1f1f1;
# }
# #T_e8729_row2_col18 {
#   background-color: #8c6ab1;
#   color: #f1f1f1;
# }
# #T_e8729_row2_col24 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_e8729_row3_col0 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_e8729_row3_col5, #T_e8729_row4_col28, #T_e8729_row4_col30 {
#   background-color: #b5cce3;
#   color: #000000;
# }
# #T_e8729_row3_col10 {
#   background-color: #b3cbe2;
#   color: #000000;
# }
# #T_e8729_row3_col16 {
#   background-color: #cadbeb;
#   color: #000000;
# }
# #T_e8729_row3_col17 {
#   background-color: #6c0968;
#   color: #f1f1f1;
# }
# #T_e8729_row3_col27 {
#   background-color: #852d90;
#   color: #f1f1f1;
# }
# #T_e8729_row4_col3 {
#   background-color: #b7cee3;
#   color: #000000;
# }
# #T_e8729_row4_col16 {
#   background-color: #a4c0dc;
#   color: #000000;
# }
# #T_e8729_row4_col17 {
#   background-color: #8c69b0;
#   color: #f1f1f1;
# }
# #T_e8729_row4_col20 {
#   background-color: #e8f1f7;
#   color: #000000;
# }
# #T_e8729_row4_col27 {
#   background-color: #ccddec;
#   color: #000000;
# }
# </style>
# <table id="T_e8729">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8729_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_e8729_level0_col1" class="col_heading level0 col1" >Attrition</th>
#       <th id="T_e8729_level0_col2" class="col_heading level0 col2" >BusinessTravel</th>
#       <th id="T_e8729_level0_col3" class="col_heading level0 col3" >DailyRate</th>
#       <th id="T_e8729_level0_col4" class="col_heading level0 col4" >Department</th>
#       <th id="T_e8729_level0_col5" class="col_heading level0 col5" >DistanceFromHome</th>
#       <th id="T_e8729_level0_col6" class="col_heading level0 col6" >Education</th>
#       <th id="T_e8729_level0_col7" class="col_heading level0 col7" >EducationField</th>
#       <th id="T_e8729_level0_col8" class="col_heading level0 col8" >EnvironmentSatisfaction</th>
#       <th id="T_e8729_level0_col9" class="col_heading level0 col9" >Gender</th>
#       <th id="T_e8729_level0_col10" class="col_heading level0 col10" >HourlyRate</th>
#       <th id="T_e8729_level0_col11" class="col_heading level0 col11" >JobInvolvement</th>
#       <th id="T_e8729_level0_col12" class="col_heading level0 col12" >JobLevel</th>
#       <th id="T_e8729_level0_col13" class="col_heading level0 col13" >JobRole</th>
#       <th id="T_e8729_level0_col14" class="col_heading level0 col14" >JobSatisfaction</th>
#       <th id="T_e8729_level0_col15" class="col_heading level0 col15" >MaritalStatus</th>
#       <th id="T_e8729_level0_col16" class="col_heading level0 col16" >MonthlyIncome</th>
#       <th id="T_e8729_level0_col17" class="col_heading level0 col17" >MonthlyRate</th>
#       <th id="T_e8729_level0_col18" class="col_heading level0 col18" >NumCompaniesWorked</th>
#       <th id="T_e8729_level0_col19" class="col_heading level0 col19" >OverTime</th>
#       <th id="T_e8729_level0_col20" class="col_heading level0 col20" >PercentSalaryHike</th>
#       <th id="T_e8729_level0_col21" class="col_heading level0 col21" >PerformanceRating</th>
#       <th id="T_e8729_level0_col22" class="col_heading level0 col22" >RelationshipSatisfaction</th>
#       <th id="T_e8729_level0_col23" class="col_heading level0 col23" >StockOptionLevel</th>
#       <th id="T_e8729_level0_col24" class="col_heading level0 col24" >TotalWorkingYears</th>
#       <th id="T_e8729_level0_col25" class="col_heading level0 col25" >TrainingTimesLastYear</th>
#       <th id="T_e8729_level0_col26" class="col_heading level0 col26" >WorkLifeBalance</th>
#       <th id="T_e8729_level0_col27" class="col_heading level0 col27" >YearsAtCompany</th>
#       <th id="T_e8729_level0_col28" class="col_heading level0 col28" >YearsInCurrentRole</th>
#       <th id="T_e8729_level0_col29" class="col_heading level0 col29" >YearsSinceLastPromotion</th>
#       <th id="T_e8729_level0_col30" class="col_heading level0 col30" >YearsWithCurrManager</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8729_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8729_row0_col0" class="data row0 col0" >41</td>
#       <td id="T_e8729_row0_col1" class="data row0 col1" >Yes</td>
#       <td id="T_e8729_row0_col2" class="data row0 col2" >Travel_Rarely</td>
#       <td id="T_e8729_row0_col3" class="data row0 col3" >1102</td>
#       <td id="T_e8729_row0_col4" class="data row0 col4" >Sales</td>
#       <td id="T_e8729_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e8729_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_e8729_row0_col7" class="data row0 col7" >Life Sciences</td>
#       <td id="T_e8729_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_e8729_row0_col9" class="data row0 col9" >Female</td>
#       <td id="T_e8729_row0_col10" class="data row0 col10" >94</td>
#       <td id="T_e8729_row0_col11" class="data row0 col11" >3</td>
#       <td id="T_e8729_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_e8729_row0_col13" class="data row0 col13" >Sales Executive</td>
#       <td id="T_e8729_row0_col14" class="data row0 col14" >4</td>
#       <td id="T_e8729_row0_col15" cl

# %% [markdown]
# Consider two dataframes, `num` and `cat`, containing _quantitative_ and _qualitative_ data respectively.

# %%
num = data.select_dtypes(exclude='string')
display(num.head())
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# 0          94               3         2                4           5993  ...
# 1          61               2         2                2           5130  ...
# 2          92               2         1                3           2090  ...
# 3          56               3         1                3           2909  ...
# 4          40               3         1                2           3468  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         1                 0
# 1                  4                         4                 1
# 2                  3                         2                 0
# 3                  3                         3                 0
# 4                  3                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 23 columns]

# %%
cat = data.select_dtypes(include='string')
display(cat.head())
# Out:
#   Attrition     BusinessTravel              Department EducationField  Gender  \
# 0       Yes      Travel_Rarely                   Sales  Life Sciences  Female
# 1        No  Travel_Frequently  Research & Development  Life Sciences    Male
# 2       Yes      Travel_Rarely  Research & Development          Other    Male
# 3        No  Travel_Frequently  Research & Development  Life Sciences  Female
# 4        No      Travel_Rarely  Research & Development        Medical    Male
#
#                  JobRole MaritalStatus OverTime
# 0        Sales Executive        Single      Yes
# 1     Research Scientist       Married       No
# 2  Laboratory Technician        Single      Yes
# 3     Research Scientist       Married      Yes
# 4  Laboratory Technician       Married       No

# %% [markdown]
# ##### <span style="color:purple"> **Question:**  What is the proportion of qualitative data in this dataset? Of quantitative data?</span>

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/data_proportion.py
prop_num = 100 * num.shape[1] / data.shape[1]
prop_cat = 100 * cat.shape[1] / data.shape[1]

print(f"Quantitative variables: {prop_num:.2f}%")
print(f"Qualitative variables: {prop_cat:.2f}%")
# Out:
# Quantitative variables: 74.19%
# Qualitative variables: 25.81%

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** For each variable, display its basic statistical descriptors: variable, mean, quantiles, _etc._</span>

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/stat_summary.py
# print( data.describe().T )
display( 
    data.describe().T.style.background_gradient(cmap='BuPu') 
)
# Out:
# <style type="text/css">
# #T_1fdce_row0_col0, #T_1fdce_row0_col1, #T_1fdce_row0_col2, #T_1fdce_row0_col4, #T_1fdce_row0_col5, #T_1fdce_row0_col6, #T_1fdce_row0_col7, #T_1fdce_row1_col0, #T_1fdce_row2_col0, #T_1fdce_row2_col1, #T_1fdce_row2_col2, #T_1fdce_row2_col3, #T_1fdce_row2_col4, #T_1fdce_row2_col5, #T_1fdce_row2_col6, #T_1fdce_row2_col7, #T_1fdce_row3_col0, #T_1fdce_row3_col1, #T_1fdce_row3_col2, #T_1fdce_row3_col3, #T_1fdce_row3_col4, #T_1fdce_row3_col5, #T_1fdce_row3_col6, #T_1fdce_row3_col7, #T_1fdce_row4_col0, #T_1fdce_row4_col1, #T_1fdce_row4_col2, #T_1fdce_row4_col3, #T_1fdce_row4_col4, #T_1fdce_row4_col5, #T_1fdce_row4_col6, #T_1fdce_row4_col7, #T_1fdce_row5_col0, #T_1fdce_row5_col2, #T_1fdce_row5_col7, #T_1fdce_row6_col0, #T_1fdce_row6_col1, #T_1fdce_row6_col2, #T_1fdce_row6_col3, #T_1fdce_row6_col4, #T_1fdce_row6_col5, #T_1fdce_row6_col6, #T_1fdce_row6_col7, #T_1fdce_row7_col0, #T_1fdce_row7_col1, #T_1fdce_row7_col2, #T_1fdce_row7_col3, #T_1fdce_row7_col4, #T_1fdce_row7_col5, #T_1fdce_row7_col6, #T_1fdce_row7_col7, #T_1fdce_row8_col0, #T_1fdce_row8_col1, #T_1fdce_row8_col2, #T_1fdce_row8_col3, #T_1fdce_row8_col4, #T_1fdce_row8_col5, #T_1fdce_row8_col6, #T_1fdce_row8_col7, #T_1fdce_row9_col0, #T_1fdce_row10_col0, #T_1fdce_row11_col0, #T_1fdce_row11_col1, #T_1fdce_row11_col2, #T_1fdce_row11_col3, #T_1fdce_row11_col4, #T_1fdce_row11_col5, #T_1fdce_row11_col6, #T_1fdce_row11_col7, #T_1fdce_row12_col0, #T_1fdce_row12_col1, #T_1fdce_row12_col2, #T_1fdce_row12_col4, #T_1fdce_row12_col5, #T_1fdce_row12_col6, #T_1fdce_row12_col7, #T_1fdce_row13_col0, #T_1fdce_row13_col1, #T_1fdce_row13_col2, #T_1fdce_row13_col3, #T_1fdce_row13_col4, #T_1fdce_row13_col5, #T_1fdce_row13_col6, #T_1fdce_row13_col7, #T_1fdce_row14_col0, #T_1fdce_row14_col1, #T_1fdce_row14_col2, #T_1fdce_row14_col3, #T_1fdce_row14_col4, #T_1fdce_row14_col5, #T_1fdce_row14_col6, #T_1fdce_row14_col7, #T_1fdce_row15_col0, #T_1fdce_row15_col1, #T_1fdce_row15_col2, #T_1fdce_row15_col3, #T_1fdce_row15_col4, #T_1fdce_row15_col5, #T_1fdce_row15_col6, #T_1fdce_row15_col7, #T_1fdce_row16_col0, #T_1fdce_row16_col1, #T_1fdce_row16_col2, #T_1fdce_row16_col3, #T_1fdce_row16_col4, #T_1fdce_row16_col5, #T_1fdce_row16_col6, #T_1fdce_row16_col7, #T_1fdce_row17_col0, #T_1fdce_row17_col1, #T_1fdce_row17_col2, #T_1fdce_row17_col3, #T_1fdce_row17_col4, #T_1fdce_row17_col5, #T_1fdce_row17_col6, #T_1fdce_row17_col7, #T_1fdce_row18_col0, #T_1fdce_row18_col1, #T_1fdce_row18_col2, #T_1fdce_row18_col3, #T_1fdce_row18_col4, #T_1fdce_row18_col5, #T_1fdce_row18_col6, #T_1fdce_row18_col7, #T_1fdce_row19_col0, #T_1fdce_row19_col1, #T_1fdce_row19_col2, #T_1fdce_row19_col3, #T_1fdce_row19_col4, #T_1fdce_row19_col5, #T_1fdce_row19_col6, #T_1fdce_row19_col7, #T_1fdce_row20_col0, #T_1fdce_row20_col1, #T_1fdce_row20_col2, #T_1fdce_row20_col3, #T_1fdce_row20_col4, #T_1fdce_row20_col5, #T_1fdce_row20_col6, #T_1fdce_row20_col7, #T_1fdce_row21_col0, #T_1fdce_row21_col1, #T_1fdce_row21_col2, #T_1fdce_row21_col3, #T_1fdce_row21_col4, #T_1fdce_row21_col5, #T_1fdce_row21_col6, #T_1fdce_row21_col7, #T_1fdce_row22_col0, #T_1fdce_row22_col1, #T_1fdce_row22_col2, #T_1fdce_row22_col3, #T_1fdce_row22_col4, #T_1fdce_row22_col5, #T_1fdce_row22_col6, #T_1fdce_row22_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_1fdce_row0_col3 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_1fdce_row1_col1, #T_1fdce_row1_col2, #T_1fdce_row1_col4, #T_1fdce_row1_col5, #T_1fdce_row1_col6, #T_1fdce_row1_col7 {
#   background-color: #edf5f9;
#   color: #000000;
# }
# #T_1fdce_row1_col3 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_1fdce_row5_col1, #T_1fdce_row5_col4, #T_1fdce_row5_col5, #T_1fdce_row5_col6, #T_1fdce_row12_col3 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_1fdce_row5_col3 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_1fdce_row9_col1 {
#   background-color: #92a4cd;
#   color: #f1f1f1;
# }
# #T_1fdce_row9_col2 {
#   background-color: #8b5eab;
#   color: #f1f1f1;
# }
# #T_1fdce_row9_col3 {
#   background-color: #8f9bc9;
#   color: #f1f1f1;
# }
# #T_1fdce_row9_col4 {
#   background-color: #a2bfdb;
#   color: #000000;
# }
# #T_1fdce_row9_col5 {
#   background-color: #a6c2dd;
#   color: #000000;
# }
# #T_1fdce_row9_col6 {
#   background-color: #99b2d5;
#   color: #000000;
# }
# #T_1fdce_row9_col7 {
#   background-color: #88449e;
#   color: #f1f1f1;
# }
# #T_1fdce_row10_col1, #T_1fdce_row10_col2, #T_1fdce_row10_col3, #T_1fdce_row10_col4, #T_1fdce_row10_col5, #T_1fdce_row10_col6, #T_1fdce_row10_col7 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1fdce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fdce_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_1fdce_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_1fdce_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_1fdce_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_1fdce_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_1fdce_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_1fdce_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_1fdce_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fdce_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_1fdce_row0_col0" class="data row0 col0" >1470.000000</td>
#       <td id="T_1fdce_row0_col1" class="data row0 col1" >36.923810</td>
#       <td id="T_1fdce_row0_col2" class="data row0 col2" >9.135373</td>
#       <td id="T_1fdce_row0_col3" class="data row0 col3" >18.000000</td>
#       <td id="T_1fdce_row0_col4" class="data row0 col4" >30.000000</td>
#       <td id="T_1fdce_row0_col5" class="data row0 col5" >36.000000</td>
#       <td id="T_1fdce_row0_col6" class="data row0 col6" >43.000000</td>
#       <td id="T_1fdce_row0_col7" class="data row0 col7" >60.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fdce_level0_row1" class="row_heading level0 row1" >DailyRate</th>
#       <td id="T_1fdce_row1_col0" class="data row1 col0" >1470.000000</td>
#       <td id="T_1fdce_row1_col1" class="data row1 col1" >802.485714</td>
#       <td id="T_1fdce_row1_col2" class="data row1 col2" >403.509100</td>
#       <td id="T_1fdce_row1_col3" class="data row1 col3" >102.000000</td>
#       <td id="T_1fdce_row1_col4" class="data row1 col4" >465.000000</td>
#       <td id="T_1fdce_row1_col5" class="data row1 col5" >802.000000</td>
#       <td id="T_1fdce_row1_col6" class="data row1 col6" >1157.000000</td>
#       <td id="T_1fdce_row1_col7" class="data row1 col7" >1499.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fdce_level0_row2" class="row_heading level0 row2" >DistanceFromHome</th>
#       <td id="T_1fdce_row2_col0" class="data row2 col0" >1470.000000</td>
#       <td id="T_1fdce_row2_col1" class="data row2 col1" >9.192517</td>
#       <td id="T_1fdce_row2_col2" class="data row2 col2" >8.106864</td>
#       <td id="T_1fdce_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_1fdce_row2_col4" class="data row2 col4" >2.000000</td>
#       <td id="T_1fdce_row2_col5" class="data row2 col5" >7.000000</td>
#       <td id="T_1fdce_row2_col6" class="data row2 col6" >14.000000</td>
#       <td id="T_1fdce_row2_col7" class="data row2 col7" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fdce_level0_row3" class="row_heading level0 row3" >Education</th>
#       <td id="T_1fdce_row3_col0" class="data row3 col0" >1470.000000</td>
#       <td id="T_1fdce_row3_col1" class="data row3 col1" >2.912925</td>
#       <td id="T_1fdce_row3_col2" class="data row3 col2" >1.024165</td>
#       <td id="T_1fdce_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1fdce_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_1fdce_row3_col5" class="data row3 col5" >3.000000</td>
#       <td id="T_1fdce_row3_col6" class="data row3 col6" >4.000000</td>
#       <td id="T_1fdce_row3_col7" class="data row3 col7" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1fdce_l

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Assess the correlation between variables.</span>
#
# 1. Plot the Correlation Matrix between variables,
# 2. You can select columns with high correlation:

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/data_correlation.py
plt.figure(figsize=(18,9))

# correlation between columns
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt='.1f')
plt.xticks(rotation=40)

plt.show()

# --- #

# strong correlation between columns
cols = ['Education','Age','MonthlyIncome','JobLevel','NumCompaniesWorked','TotalWorkingYears','YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
sns.heatmap(data[cols].corr(), annot=True, fmt='.1f')
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Draw a pairplot for the 5 highest correlation variable.</span>
#
# Color the observations according to their attribution.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/data_pairplot.py
cols = ['TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'Attrition']

sns.pairplot(data[cols], hue = 'Attrition', palette={'Yes': 'mediumvioletred', 'No': 'cornflowerblue'})
plt.show()

# %% [markdown]
# According to the figure above, attrition appears to be strongly correlated with employees' career history.
#
# ##### <span style="color:purple"> **Todo:** Represent attrition according to the worker's historical profile.</span>
#
# - Plot the total number of years worked as a function of (i) the number of years spent in this company, (ii) the number of years spent in the current position and, finally, (iii) the number of years since the last promotion.
# - Colour the dots according to attrition.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/history.py
cols = ['YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion']

fig,axes = plt.subplots(nrows=3, ncols=1, figsize=(10,10))

for i,c in enumerate(cols):
    sns.pointplot(x=data[c], y=data['TotalWorkingYears'], ax=axes[i], hue=data['Attrition'], palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
    axes[i].set_xlabel(c)
    axes[i].set_ylabel('TotalWorkingYears')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Comments.

# %% [markdown]
# ## Data Visualization¶

# %% [markdown]
# ### Breakdown of Overtime Work

# %% [markdown]
# ##### <span style="color:purple"> **Question:** What is the profile of employees working overtime?</span>
#
# View the distribution of overtime hours worked according to, for example, employees' marital status, department of practice, gender or age.
#
# You can use the [histplot](https://seaborn.pydata.org/generated/seaborn.histplot.html#seaborn.histplot) function.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/overtime.py
plt.figure(figsize=(10,8))

# --- #

plt.subplot(2,2,1)
sns.histplot(data, x="MaritalStatus", hue="OverTime", palette="rocket")
plt.title('Overtime by Marital Status')

# --- #

plt.subplot(2,2,2)
sns.histplot(data, x="Department", hue="OverTime", palette="rocket")
# plt.xticks(rotation=35)
plt.title('Overtime by Department')

# --- #

plt.subplot(2,2,3)
sns.histplot(data, x="Gender", hue="OverTime", palette="rocket")
plt.title('Overtime by Gender')

# --- #

plt.subplot(2,2,4)
sns.histplot(data, x='Age', hue='OverTime', palette="rocket", kde=True)
plt.title('Distribution of Age by OverTime')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Comments.

# %% [markdown]
# ## Company Departure

# %% [markdown]
# ##### <span style="color:purple"> **Question:** What is the profile of employees working overtime?</span>
#
# Carry out the same exploratory study, but distinguish between employees who leave the company (attrition) and those who do not.

# %%
### TO BE COMPLETED ###

[...]

# %%
# %load solutions/attrition.py
plt.figure(figsize=(10,8))

# --- #

plt.subplot(2,2,1)
sns.histplot(data, x="MaritalStatus", hue="Attrition", palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
plt.title('Attrition by Marital Status')

# --- #

plt.subplot(2,2,2)
sns.histplot(data, x="Department", hue="Attrition", palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
# plt.xticks(rotation=35)
plt.title('Attrition by Department')

# --- #

plt.subplot(2,2,3)
sns.histplot(data, x="Gender", hue="Attrition", palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'})
plt.title('Attrition by Gender')

# --- #

plt.subplot(2,2,4)
sns.histplot(data, x='Age', hue='Attrition', palette={'Yes':'mediumvioletred', 'No':'cornflowerblue'}, kde=True)
plt.title('Distribution of Age by Attrition')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Comments.

# %% [markdown]
# ## One-hot Encoding of Categorical Data
#
# To facilitate statistical analysis (LDA decomposition), we will "translate" the various categorical variables into [one-hot](https://fr.wikipedia.org/wiki/Encodage_one-hot) encoder form.

# %% [markdown]
# ### Attrition

# %%
data['Attrition'] = data['Attrition'].map({'No': 0, 'Yes': 1}).astype(int)

# %% [markdown]
# ### Business Travel

# %%
data = pd.get_dummies(data, columns=['BusinessTravel'], prefix='Business')

# %% [markdown]
# ### Working Department

# %%
DPT_names = ['Sales', 'R & D', 'Dpt HR']

dummies = pd.get_dummies(data['Department'])
dummies.columns = DPT_names
data = pd.concat([data.drop('Department', axis=1), dummies], axis=1)
# data.head()

# %% [markdown]
# ### Education Field

# %%
EDUC_names = ['Life Sciences', 'Other', 'Medical', 'Marketing', 'Technical Degree', 'Educ HR']

dummies = pd.get_dummies(data['EducationField'])
dummies.columns = EDUC_names
data = pd.concat([data.drop('EducationField', axis=1), dummies], axis=1)
# data.head()

# %% [markdown]
# ### Gender

# %%
data['Gender'] = data['Gender'].map({'Female': 0, 'Male': 1}).astype(int)

# %% [markdown]
# ### Job Role

# %%
JOB_names = data['JobRole'].unique()
JOB_names[-1] = 'Job HR'

dummies = pd.get_dummies(data['JobRole'])
dummies.columns = JOB_names
data = pd.concat([data.drop('JobRole', axis=1), dummies], axis=1)
# data.head()

# %% [markdown]
# ### MaritalStatus

# %%
data = pd.get_dummies(data, columns=['MaritalStatus'])

# %% [markdown]
# ### OverTime

# %%
data['OverTime'] = data['OverTime'].map({'No': 0, 'Yes': 1}).astype(int)

# %% [markdown]
# We check:

# %%
data.dtypes
# Out:
# Age                           int64
# Attrition                     int64
# DailyRate                     int64
# DistanceFromHome              int64
# Education                     int64
# EnvironmentSatisfaction       int64
# Gender                        int64
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobSatisfaction               int64
# MonthlyIncome                 int64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# OverTime                      int64
# PercentSalaryHike             int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# StockOptionLevel              int64
# TotalWorkingYears             int64
# TrainingTimesLastYear         int64
# WorkLifeBalance               int64
# YearsAtCompany                int64
# YearsInCurrentRole            int64
# YearsSinceLastPromotion       int64
# YearsWithCurrManager          int64
# Business_Non-Travel            bool
# Business_Travel_Frequently     bool
# Business_Travel_Rarely         bool
# Sales                          bool
# R & D                          bool
# Dpt HR                         bool
# Life Sciences                  bool
# Other                          bool
# Medical                        bool
# Marketing                      bool
# Technical Degree               bool
# Educ HR                        bool
# Sales Executive                bool
# Research Scientist             bool
# Laboratory Technician          bool
# Manufacturing Director         bool
# Healthcare Representative      bool
# Manager                        bool
# Sales Representative           bool
# Research Director              bool
# Job HR                         bool
# MaritalStatus_Divorced         bool
# MaritalStatus_Married          bool
# MaritalStatus_Single           bool
# dtype: object

# %% [markdown]
# ## Prediction of Attrition by **Logistic Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Using the [`train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) function, define a training and test data set.</span>

# %%
### TO BE COMPLETED ###

[...]

train_x, test_x, train_y, test_y = ...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       1 ### TO BE COMPLETED ###
#       3 [...]
# ----> 5 train_x, test_x, train_y, test_y = ...
#
# TypeError: cannot unpack non-iterable ellipsis object

# %%
# %load solutions/train_test_split.py
X = data.drop(columns='Attrition')
Y = data['Attrition']

train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.3, random_state=20)

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Implement attrition prediction using a logistic regression model.</span>

# %%
### TO BE COMPLETED ###

clf = LogisticRegression(solver='newton-cholesky')
clf.fit(...)

[...]

test_pred  = clf.predict( ... )
test_accuracy = ...

print( classification_report( ... ) )

# %%
# %load solutions/logistic_regression.py
clf = LogisticRegression(solver='newton-cholesky')
clf.fit(train_x, train_y)

# --- #

train_pred = clf.predict(train_x)
test_pred  = clf.predict(test_x)

train_accuracy = accuracy_score(train_y, train_pred)
test_accuracy  = accuracy_score(test_y, test_pred)

print("--- Logistic Regression ---\n")
print(f"Train accuracy: {train_accuracy:.2%}")
print(f"Test accuracy:  {test_accuracy:.2%}")
print(' ')

# --- #

print(classification_report(test_y, test_pred))
# Out:
# --- Logistic Regression ---
#
# Train accuracy: 89.41%
# Test accuracy:  89.12%
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       371
#            1       0.75      0.47      0.58        70
#
#     accuracy                           0.89       441
#    macro avg       0.83      0.72      0.76       441
# weighted avg       0.88      0.89      0.88       441

# %% [markdown]
# > Comments

# %% [markdown]
# ## Prediction of Attrition by **Linear Discriminant Analysis** (LDA)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Implement attrition prediction using LDA decomposition.</span>

# %%
### TO BE COMPLETED ###

[...]
# Out:
# [Ellipsis]

# %%
# %load solutions/linear_discriminant_analysis.py
clf = LinearDiscriminantAnalysis()
clf.fit(train_x, train_y)

# --- #

train_pred = clf.predict(train_x)
test_pred  = clf.predict(test_x)

train_accuracy = accuracy_score(train_y, train_pred)
test_accuracy  = accuracy_score(test_y, test_pred)

print("--- Linear Discriminant Analysis ---\n")
print(f"Train accuracy: {train_accuracy:.2%}")
print(f"Test accuracy:  {test_accuracy:.2%}")
print(' ')

# --- #

print(classification_report(test_y, test_pred))
# Out:
# --- Linear Discriminant Analysis ---
#
# Train accuracy: 89.21%
# Test accuracy:  88.21%
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       371
#            1       0.70      0.46      0.55        70
#
#     accuracy                           0.88       441
#    macro avg       0.80      0.71      0.74       441
# weighted avg       0.87      0.88      0.87       441

# %% [markdown]
# > Comments.

# %% [markdown]
# ## Prediction of Attrition by **Quadratic Discriminant Analysis** (QDA)

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %% [markdown]
# ##### <span style="color:purple"> **Todo:** Implement attrition prediction using QDA decomposition.</span>

# %%
### TO BE COMPLETED ###

[...]
# Out:
# [Ellipsis]

# %%
# %load solutions/quadratic_discriminant_analysis.py
clf = QuadraticDiscriminantAnalysis(reg_param=0.1)
clf.fit(train_x, train_y)

# --- #

train_pred = clf.predict(train_x)
test_pred  = clf.predict(test_x)

train_accuracy = accuracy_score(train_y, train_pred)
test_accuracy  = accuracy_score(test_y, test_pred)

print("--- Quadratic Discriminant Analysis ---\n")
print(f"Train accuracy: {train_accuracy:.2%}")
print(f"Test accuracy:  {test_accuracy:.2%}")
print(' ')

# --- #

print(classification_report(test_y, test_pred))
# Out:
# --- Quadratic Discriminant Analysis ---
#
# Train accuracy: 90.18%
# Test accuracy:  81.86%
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       371
#            1       0.43      0.44      0.44        70
#
#     accuracy                           0.82       441
#    macro avg       0.66      0.67      0.66       441
# weighted avg       0.82      0.82      0.82       441

# %% [markdown]
# > Comments.
